# %%
import pandas as pd
import numpy as np

# %%
description_df = pd.read_csv('ECCO.csv', encoding='iso-8859-1')
description_df
# Out:
#       RAMO RAMO SIGLAS                                   RAMO DESCRIPCION  \
# 0        2        PRES                        Presidencia de la República
# 1        2        PRES                        Presidencia de la República
# 2        2        PRES                        Presidencia de la República
# 3        2        PRES                        Presidencia de la República
# 4        2        PRES                        Presidencia de la República
# 5        2        PRES                        Presidencia de la República
# 6        2        PRES                        Presidencia de la República
# 7        2        PRES                        Presidencia de la República
# 8        4       SEGOB                          Secretaría de Gobernación
# 9        4       SEGOB                          Secretaría de Gobernación
# 10       4       SEGOB                          Secretaría de Gobernación
# 11       4       SEGOB                          Secretaría de Gobernación
# ...

# %%
ramo_description = description_df[['RAMO', 'RAMO DESCRIPCION']].copy()
ramo_description = ramo_description.drop_duplicates()
ramo_description = ramo_description.rename(columns={'RAMO':'ramo', 'RAMO DESCRIPCION':'ramo_descripcion'})
ramo_description
# Out:
#       ramo                                   ramo_descripcion
# 0        2                        Presidencia de la República
# 8        4                          Secretaría de Gobernación
# 151      5                Secretaría de Relaciones Exteriores
# 193      6           Secretaría de Hacienda y Crédito Público
# 289      6                   Secretaría de la Función Pública
# 382      7                  Secretaría de la Defensa Nacional
# 398      8  Secretaría de Agricultura Ganadería  Desarroll...
# 525      9          Secretaría de Comunicaciones y Transporte
# 752     10                             Secretaría de Economía
# 825     11                    Secretaría de Educación Pública
# 1102    12                                Secretaría de Salud
# 1405    13                               Secretaría de Marina
# 1413    14          Secretaría del Trabajo y Previsión Social
# 1452    15  Secretaria de Desarrollo Agrario, Territorial ...
# ...
